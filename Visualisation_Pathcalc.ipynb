# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')

import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='15801fd0-fb20-4e74-9e3d-39aa6e0e0125'>
#   <div id="ff627623-8d20-4486-95af-44afec1beaf9" data-root-id="15801fd0-fb20-4e74-9e3d-39aa6e0e0125" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"48561364-ac00-47d2-a4a5-c86a05766c31":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"15801fd0-fb20-4e74-9e3d-39aa6e0e0125"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"8b95d36d-8855-40f3-b76a-b6179eb16685","attributes":{"plot_id":"15801fd0-fb20-4e74-9e3d-39aa6e0e0125","comm_id":"e987fef559ee405e91841005aa7c2f93","client_comm_id":"515cebe5c9064d889af44a9d78ad7061"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":" ...
#   var render_items = [{"docid":"48561364-ac00-47d2-a4a5-c86a05766c31","roots":{"15801fd0-fb20-4e74-9e3d-39aa6e0e0125":"ff627623-8d20-4486-95af-44afec1beaf9"},"root_ids":["15801fd0-fb20-4e74-9e3d-39aa6e0e0125"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# Load data
df = pd.read_csv("Filepath")
df
# Out:
#       Scenario_Cost  Scenario_Improve  Scenario_Transform  Scenario_Shift  \
# 0             11111             11111               11111           11111
# 1             11111             11111               11111           11111
# 2             11111             11111               11111           11111
# 3             11111             11111               11111           11111
# 4             11111             11111               11111           11111
# ...             ...               ...                 ...             ...
# 3402          11144             11144               11144           11144
# 3403          11144             11144               11144           11144
# 3404          11144             11144               11144           11144
# 3405          11144             11144               11144           11144
# 3406          11144             11144               11144           11144
#
#       Scenario_Avoid REGION                   TECHNOLOGY EMISSION  \
# 0              11111    RE1         Motorcycles Gasoline  CO2_TRA
# 1              11111    RE1         Motorcycles Gasoline  CO2_TRA
# 2              11111    RE1         Motorcycles Gasoline  CO2_TRA
# 3              11111    RE1         Motorcycles Gasoline  CO2_TRA
# 4              11111    RE1         Motorcycles Gasoline  CO2_TRA
# ...              ...    ...                          ...      ...
# 3402           11144    RE1  Aviation Frieght on JET/ABF  CO2_TRA
# 3403           11144    RE1  Aviation Frieght on JET/ABF  CO2_TRA
# 3404           11144    RE1  Aviation Frieght on JET/ABF  CO2_TRA
# 3405           11144    RE1  Aviation Frieght on JET/ABF  CO2_TRA
# 3406           11144    RE1  Aviation Frieght on JET/ABF  CO2_TRA
#
#       MODE_OF_OPERATION  YEAR     VALUE
# 0                     1  2021  1.344660
# 1                     1  2022  1.425690
# 2                     1  2023  1.511100
# 3                     1  2024  1.601620
# 4                     1  2025  1.697980
# ...                 ...   ...       ...
# 3402                  1  2051  1.199092
# 3403                  1  2052  1.227025
# 3404                  1  2053  1.254957
# 3405                  1  2054  1.284219
# 3406                  1  2055  1.313482
#
# [3407 rows x 11 columns]

# %%
# Fill NaN values with 0
df.fillna(0, inplace=True)

# %%
# Define Panel widgets
year_slider = pn.widgets.IntSlider(name='Year slider', start=2020, end=2055, step=1, value=2035)
year_slider
# Out:
# IntSlider(end=2055, name='Year slider', start=2020, value=2035)

# %%
# Create  scenarios Buttons
scenario_buttons = pn.widgets.RadioButtonGroup(name='Scenario', options=['Avoid', 'Shift', 'Improve', 'Transform', 'Cost'],
                   button_type='success'
)

# %%
#Ambition Slider
ambition_Slider = pn.widgets.IntSlider(name='ambition_level', start=1, end=4, step=1, value=2)
ambition_Slider
# Out:
# IntSlider(end=4, name='ambition_level', start=1, value=2)

# %%
# Define weights
weights = [1, 1, 1,1,1]  # Adjust these weights as needed for your scenario

# %%
def create_pipeline(df, weights):
    try:
        # Copy the dataframe to avoid modifying the original
        filtered_df = df.copy()

        # Start with the first condition
        mask = (filtered_df['Scenarios'] * weights[0]) > 0

        # Combine conditions for each subsequent weight
        for weight in weights[1:]:
            mask &= (filtered_df['Scenarios'] * weight) > 0

        # Apply the mask to filter the dataframe
        filtered_df = filtered_df[mask]

        # Group by 'TECHNOLOGY' and 'YEAR' columns, then sum the remaining data
        return filtered_df.groupby(['TECHNOLOGY', 'YEAR']).mean()
    except KeyError as e:
        print(f"Error: Missing column {e}")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None
df
# Out:
#       Scenario_Cost  Scenario_Improve  Scenario_Transform  Scenario_Shift  \
# 0             11111             11111               11111           11111
# 1             11111             11111               11111           11111
# 2             11111             11111               11111           11111
# 3             11111             11111               11111           11111
# 4             11111             11111               11111           11111
# ...             ...               ...                 ...             ...
# 3402          11144             11144               11144           11144
# 3403          11144             11144               11144           11144
# 3404          11144             11144               11144           11144
# 3405          11144             11144               11144           11144
# 3406          11144             11144               11144           11144
#
#       Scenario_Avoid REGION                   TECHNOLOGY EMISSION  \
# 0              11111    RE1         Motorcycles Gasoline  CO2_TRA
# 1              11111    RE1         Motorcycles Gasoline  CO2_TRA
# 2              11111    RE1         Motorcycles Gasoline  CO2_TRA
# 3              11111    RE1         Motorcycles Gasoline  CO2_TRA
# 4              11111    RE1         Motorcycles Gasoline  CO2_TRA
# ...              ...    ...                          ...      ...
# 3402           11144    RE1  Aviation Frieght on JET/ABF  CO2_TRA
# 3403           11144    RE1  Aviation Frieght on JET/ABF  CO2_TRA
# 3404           11144    RE1  Aviation Frieght on JET/ABF  CO2_TRA
# 3405           11144    RE1  Aviation Frieght on JET/ABF  CO2_TRA
# 3406           11144    RE1  Aviation Frieght on JET/ABF  CO2_TRA
#
#       MODE_OF_OPERATION  YEAR     VALUE
# 0                     1  2021  1.344660
# 1                     1  2022  1.425690
# 2                     1  2023  1.511100
# 3                     1  2024  1.601620
# 4                     1  2025  1.697980
# ...                 ...   ...       ...
# 3402                  1  2051  1.199092
# 3403                  1  2052  1.227025
# 3404                  1  2053  1.254957
# 3405                  1  2054  1.284219
# 3406                  1  2055  1.313482
#
# [3407 rows x 11 columns]

# %%
df.reset_index(inplace=True)
df
# Out:
#       index  Scenario_Cost  Scenario_Improve  Scenario_Transform  \
# 0         0          11111             11111               11111
# 1         1          11111             11111               11111
# 2         2          11111             11111               11111
# 3         3          11111             11111               11111
# 4         4          11111             11111               11111
# ...     ...            ...               ...                 ...
# 3402   3402          11144             11144               11144
# 3403   3403          11144             11144               11144
# 3404   3404          11144             11144               11144
# 3405   3405          11144             11144               11144
# 3406   3406          11144             11144               11144
#
#       Scenario_Shift  Scenario_Avoid REGION                   TECHNOLOGY  \
# 0              11111           11111    RE1         Motorcycles Gasoline
# 1              11111           11111    RE1         Motorcycles Gasoline
# 2              11111           11111    RE1         Motorcycles Gasoline
# 3              11111           11111    RE1         Motorcycles Gasoline
# 4              11111           11111    RE1         Motorcycles Gasoline
# ...              ...             ...    ...                          ...
# 3402           11144           11144    RE1  Aviation Frieght on JET/ABF
# 3403           11144           11144    RE1  Aviation Frieght on JET/ABF
# 3404           11144           11144    RE1  Aviation Frieght on JET/ABF
# 3405           11144           11144    RE1  Aviation Frieght on JET/ABF
# 3406           11144           11144    RE1  Aviation Frieght on JET/ABF
#
#      EMISSION  MODE_OF_OPERATION  YEAR     VALUE
# 0     CO2_TRA                  1  2021  1.344660
# 1     CO2_TRA                  1  2022  1.425690
# 2     CO2_TRA                  1  2023  1.511100
# 3     CO2_TRA                  1  2024  1.601620
# 4     CO2_TRA                  1  2025  1.697980
# ...       ...                ...   ...       ...
# 3402  CO2_TRA                  1  2051  1.199092
# 3403  CO2_TRA                  1  2052  1.227025
# 3404  CO2_TRA                  1  2053  1.254957
# 3405  CO2_TRA                  1  2054  1.284219
# 3406  CO2_TRA                  1  2055  1.313482
#
# [3407 rows x 12 columns]

# %%
df = df.groupby(['YEAR', 'TECHNOLOGY']).agg({'VALUE': 'sum'}).reset_index()
df
# Out:
#      YEAR                          TECHNOLOGY       VALUE
# 0    2021         Aviation Frieght on JET/ABF    5.273878
# 1    2021       Aviation Passenger on JET/ABF    0.802131
# 2    2021        Diesel and Bio Diesel Busses    2.085720
# 3    2021    Diesel cars With Blending option    5.733624
# 4    2021  Gasoline Cars With blending option   20.684664
# ..    ...                                 ...         ...
# 267  2055        Diesel and Bio Diesel Busses    8.632764
# 268  2055  Gasoline Cars With blending option  104.783364
# 269  2055                Gasoline Hybrid cars    1.006817
# 270  2055             HDV Diesel & Bio Diesel    6.880192
# 271  2055             LDV Diesel & Bio Diesel    2.048800
#
# [272 rows x 3 columns]

# %%
co2_plot = df.hvplot.area(x='YEAR', y='VALUE', by='TECHNOLOGY', label="Emissions in Mtons", ylim=(0, 100), width=1000, height=400).opts(bgcolor='white')
df
# Out:
#      YEAR                          TECHNOLOGY       VALUE
# 0    2021         Aviation Frieght on JET/ABF    5.273878
# 1    2021       Aviation Passenger on JET/ABF    0.802131
# 2    2021        Diesel and Bio Diesel Busses    2.085720
# 3    2021    Diesel cars With Blending option    5.733624
# 4    2021  Gasoline Cars With blending option   20.684664
# ..    ...                                 ...         ...
# 267  2055        Diesel and Bio Diesel Busses    8.632764
# 268  2055  Gasoline Cars With blending option  104.783364
# 269  2055                Gasoline Hybrid cars    1.006817
# 270  2055             HDV Diesel & Bio Diesel    6.880192
# 271  2055             LDV Diesel & Bio Diesel    2.048800
#
# [272 rows x 3 columns]

# %%
# Define the plot
co2_plot = df.hvplot.area(x='YEAR', y='VALUE', by='TECHNOLOGY',label= "Emissions in Mtons",ylim=(0, 100), width=1000, height=400).opts(bgcolor='white')

# Define a function that updates the plot, which is linked to some interactive controls like sliders
def update_plot():
    # Modify the plot or dataframe based on slider input and return updated plot
    # This is a simple placeholder function for demonstration
    return df.hvplot.area(x='YEAR', by='TECHNOLOGY',y='VALUE',label= "Emissions in Mtons",ylim=(0, 100), width=1000, height=400).opts(bgcolor='white')#, ambition_level)

# Create a slider using Panel
#ambition_slider = pn.widgets.FloatSlider(name='Ambition Level', start=0, end=4.0, step=1.0, value=2.0)

# Register the callback function to update the plot
interactive_plot = pn.interact(update_plot)#, ambition_level=ambition_slider)

# Display the interactive plot
#interactive_plot.show()

# %%
# Create Panel template
template = pn.template.FastListTemplate(
    title='Path Calculator Dashboard', 
    sidebar=[pn.pane.Markdown("# CO2 Emissions"), year_slider,scenario_buttons],
    main=[update_plot],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",               
)

# Display the app
template.servable()
# Out:
# FastListTemplate
#     [js_area] HTML(None, height=0, margin=0, sizing_mode='fixed', width=0)
#     [actions] TemplateActions()
#     [browser_info] BrowserInfo(dark_mode=False, device_pixel_ratio=1.7999999523162842, language='en-US', timezone='Europe/London', timezone_offset=-60, webdriver=False)
#     [busy_indicator] LoadingSpinner(height=20, width=20)
#     [main-5092788752] Column(sizing_mode='fixed')
#         [0] Column()
#         [1] Row(sizing_mode='fixed')
#             [0] HoloViews(NdOverlay, height=400, name='interactive02324', sizing_mode='fixed', width=1000)
#     [nav-5093147088] Markdown(str)
#     [nav-5094518048] IntSlider(end=2055, name='Year slider', start=2020, value=2035)
#     [nav-5094521456] RadioButtonGroup(button_type='success', name='Scenario', options=['Avoid', 'Shift', ...], value='Avoid')
